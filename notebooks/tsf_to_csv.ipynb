# %%
import os
import pandas as pd
from google.colab import files

# %%
# !git clone https://github.com/lordlordone/RISE-TS.git
# Out:
# fatal: destination path 'RISE-TS' already exists and is not an empty directory.

# %%
import sys
sys.path.append('/content/RISE-TS/src/')
from utils.tsf_parser import open_tsf_format, set_long_df_format

# %%
loaded_data, frequency, forecast_horizon, contain_missing_values, contain_equal_length = open_tsf_format("/content/RISE-TS/datasets/electricity_hourly_dataset.tsf")
print(f'frequency: {frequency}')
loaded_data.head()
# Out:
# frequency: hourly
#   series_name     start_timestamp  \
# 0          T1 2012-01-01 00:00:01
# 1          T2 2012-01-01 00:00:01
# 2          T3 2012-01-01 00:00:01
# 3          T4 2012-01-01 00:00:01
# 4          T5 2012-01-01 00:00:01
#
#                                         series_value
# 0  [14.0, 18.0, 21.0, 20.0, 22.0, 20.0, 20.0, 20....
# 1  [69.0, 92.0, 96.0, 92.0, 91.0, 92.0, 91.0, 92....
# 2  [234.0, 312.0, 312.0, 312.0, 312.0, 187.0, 138...
# 3  [415.0, 556.0, 560.0, 443.0, 346.0, 340.0, 376...
# 4  [215.0, 292.0, 272.0, 213.0, 190.0, 178.0, 199...

# %%
# Splitting the dataframe into 3 parts since the file exceeds GitHub's 100 MB upload limit.
set_long_df_format(loaded_data[0:100], frequency, "electricity_hourly_dataset_1.csv")
set_long_df_format(loaded_data[100:200], frequency, "electricity_hourly_dataset_2.csv")
set_long_df_format(loaded_data[200:], frequency, "electricity_hourly_dataset_3.csv")

# %%
# downloading files
files.download("electricity_hourly_dataset_1.csv")
files.download("electricity_hourly_dataset_2.csv")
files.download("electricity_hourly_dataset_3.csv")

# %%
def concat_splitted_df():
  files = sorted( [file for file in os.listdir('/content/') if file.endswith('.csv')] )
  for file in files:
    if '1' in file:
      df = pd.read_csv(file)
    else:
      df = pd.concat([df, pd.read_csv(file)])
  return df


df = concat_splitted_df()
df.head()
# Out:
#   unique_id     y                   ds
# 0        T1  14.0  2012-01-01 00:00:01
# 1        T1  18.0  2012-01-01 01:00:01
# 2        T1  21.0  2012-01-01 02:00:01
# 3        T1  20.0  2012-01-01 03:00:01
# 4        T1  22.0  2012-01-01 04:00:01
